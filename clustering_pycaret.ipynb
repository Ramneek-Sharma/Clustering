# %%
# !pip install scikit-learn==0.23.2
# !pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 44.9 MB/s eta 0:00:00
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Installing build dependencies ... error
# error: subprocess-exited-with-error
#
# × pip subprocess to install build dependencies did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   Using cached scipy-1.11.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.8/165.8 kB 8.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.6/50.6 kB 3.5 MB/s eta 0:00:00
# ...

# %%
from pycaret.clustering import *
import pandas as pd
from sklearn.datasets import load_iris

# %%
iris = load_iris()
X=iris.data

# %%
algorithms = ['No data processing(c=3)','No data processing(c=4)','No data processing(c=5)', 'Normalized(c=3)', 'Normalized(c=4)','Normalized(c=5)','Transform(c=3)','Transform(c=4)','Transform(c=5)','PCA(c=3)','PCA(c=4)','PCA(c=5)','T+N(c=3)','T+N(c=4)','T+N(c=5)','T+N+P(c=3)','T+N+P(c=4)','T+N+P(c=5)']
parameter = ['Silhouette', 'Calinski-Harabasz', 'Davies-Bouldin']


results_df = pd.DataFrame(index=parameter, columns=algorithms)
results_df1 = pd.DataFrame(index=parameter, columns=algorithms)
results_df2 = pd.DataFrame(index=parameter, columns=algorithms)

# %%
exp_kmeans = setup(data = X, verbose=False)

kmeans3 = create_model('kmeans', num_clusters=3)

plot_model(kmeans, plot='cluster')
plot_model(kmeans, plot='tsne')
plot_model(kmeans, plot='elbow')
plot_model(kmeans, plot='silhouette')
plot_model(kmeans, plot='distribution')
plot_model(kmeans, plot='distance')


kmeans_results3 = pull()

exp_kmeans = setup(data = X, verbose=False)
kmeans3 = create_model('kmeans', num_clusters=4)
kmeans_results4 = pull()

exp_kmeans = setup(data = X, verbose=False)
kmeans3 = create_model('kmeans', num_clusters=5)
kmeans_results5 = pull()

results_df.loc['Silhouette']['No data processing(c=3)']=kmeans_results3['Silhouette'][0]
results_df.loc['Silhouette']['No data processing(c=4)']=kmeans_results4['Silhouette'][0]
results_df.loc['Silhouette']['No data processing(c=5)']=kmeans_results5['Silhouette'][0]
results_df.loc['Calinski-Harabasz']['No data processing(c=3)']=kmeans_results3['Calinski-Harabasz'][0]
results_df.loc['Calinski-Harabasz']['No data processing(c=4)']=kmeans_results4['Calinski-Harabasz'][0]
results_df.loc['Calinski-Harabasz']['No data processing(c=5)']=kmeans_results5['Calinski-Harabasz'][0]
results_df.loc['Davies-Bouldin']['No data processing(c=3)']=kmeans_results3['Davies-Bouldin'][0]
results_df.loc['Davies-Bouldin']['No data processing(c=4)']=kmeans_results4['Davies-Bouldin'][0]
results_df.loc['Davies-Bouldin']['No data processing(c=5)']=kmeans_results5['Davies-Bouldin'][0]
# Out:
# <style type="text/css">
# </style>
# <table id="T_6881a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6881a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_6881a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_6881a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_6881a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_6881a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_6881a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6881a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6881a_row0_col0" class="data row0 col0" >0.5528</td>
#       <td id="T_6881a_row0_col1" class="data row0 col1" >561.6277</td>
# ...

# %%
results_df
# Out:
#                   No data processing(c=3) No data processing(c=4)  \
# Silhouette                         0.5512                  0.4954
# Calinski-Harabasz                561.5937                529.1967
# Davies-Bouldin                      0.666                  0.7639
#
#                   No data processing(c=5) Normalized(c=3) Normalized(c=4)  \
# Silhouette                         0.3722           0.463          0.4133
# Calinski-Harabasz                458.2908        241.4263         206.345
# Davies-Bouldin                     0.8949          0.8324          0.9266
#
#                   Normalized(c=5) Transform(c=3) Transform(c=4)  \
# Silhouette                 0.3647         0.6532         0.6165
# Calinski-Harabasz        167.2227      1161.7898      1350.7879
# Davies-Bouldin             1.0811         0.4881          0.532
#
#                   Transform(c=5)  PCA(c=3)  PCA(c=4)  PCA(c=5)  T+N(c=3)  \
# ...

# %%
exp_kmeans = setup(data = X, normalize = True, normalize_method = 'zscore', verbose=False)


kmeans3 = create_model('kmeans', num_clusters=3)

plot_model(kmeans3, plot='cluster')
plot_model(kmeans3, plot='tsne')
plot_model(kmeans3, plot='elbow')

plot_model(kmeans3, plot='distribution')
plot_model(kmeans3, plot='distance')


kmeans_results3 = pull()

kmeans3 = create_model('kmeans', num_clusters=4)
kmeans_results4 = pull()

kmeans3 = create_model('kmeans', num_clusters=5)
kmeans_results5 = pull()
results_df.loc['Silhouette']['Normalized(c=3)']=kmeans_results3['Silhouette'][0]
results_df.loc['Silhouette']['Normalized(c=4)']=kmeans_results4['Silhouette'][0]
results_df.loc['Silhouette']['Normalized(c=5)']=kmeans_results5['Silhouette'][0]
results_df.loc['Calinski-Harabasz']['Normalized(c=3)']=kmeans_results3['Calinski-Harabasz'][0]
results_df.loc['Calinski-Harabasz']['Normalized(c=4)']=kmeans_results4['Calinski-Harabasz'][0]
results_df.loc['Calinski-Harabasz']['Normalized(c=5)']=kmeans_results5['Calinski-Harabasz'][0]
results_df.loc['Davies-Bouldin']['Normalized(c=3)']=kmeans_results3['Davies-Bouldin'][0]
results_df.loc['Davies-Bouldin']['Normalized(c=4)']=kmeans_results4['Davies-Bouldin'][0]
results_df.loc['Davies-Bouldin']['Normalized(c=5)']=kmeans_results5['Davies-Bouldin'][0]
# Out:
# <style type="text/css">
# </style>
# <table id="T_62c1c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_62c1c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_62c1c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_62c1c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_62c1c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_62c1c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_62c1c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_62c1c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_62c1c_row0_col0" class="data row0 col0" >0.4599</td>
#       <td id="T_62c1c_row0_col1" class="data row0 col1" >241.9044</td>
# ...

# %%
exp_kmeans = setup(data = X, transformation = True, transformation_method = 'yeo-johnson', verbose=False)


kmeans3 = create_model('kmeans', num_clusters=3)




kmeans_results3 = pull()

kmeans3 = create_model('kmeans', num_clusters=4)
plot_model(kmeans, plot='cluster')
plot_model(kmeans, plot='tsne')
plot_model(kmeans, plot='elbow')
plot_model(kmeans, plot='silhouette')
plot_model(kmeans, plot='distribution')
plot_model(kmeans, plot='distance')
kmeans_results4 = pull()

kmeans3 = create_model('kmeans', num_clusters=5)
kmeans_results5 = pull()

results_df.loc['Silhouette']['Transform(c=3)']=kmeans_results3['Silhouette'][0]
results_df.loc['Silhouette']['Transform(c=4)']=kmeans_results4['Silhouette'][0]
results_df.loc['Silhouette']['Transform(c=5)']=kmeans_results5['Silhouette'][0]
results_df.loc['Calinski-Harabasz']['Transform(c=3)']=kmeans_results3['Calinski-Harabasz'][0]
results_df.loc['Calinski-Harabasz']['Transform(c=4)']=kmeans_results4['Calinski-Harabasz'][0]
results_df.loc['Calinski-Harabasz']['Transform(c=5)']=kmeans_results5['Calinski-Harabasz'][0]
results_df.loc['Davies-Bouldin']['Transform(c=3)']=kmeans_results3['Davies-Bouldin'][0]
results_df.loc['Davies-Bouldin']['Transform(c=4)']=kmeans_results4['Davies-Bouldin'][0]
results_df.loc['Davies-Bouldin']['Transform(c=5)']=kmeans_results5['Davies-Bouldin'][0]
# Out:
# <style type="text/css">
# </style>
# <table id="T_bc9f5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bc9f5_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_bc9f5_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_bc9f5_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_bc9f5_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_bc9f5_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_bc9f5_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bc9f5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bc9f5_row0_col0" class="data row0 col0" >0.6540</td>
#       <td id="T_bc9f5_row0_col1" class="data row0 col1" >1164.8165</td>
# ...

# %%
exp_kmeans = setup(data = X, pca = True, pca_method = 'linear', verbose=False)


kmeans3 = create_model('kmeans', num_clusters=3)

kmeans_results3 = pull()

kmeans3 = create_model('kmeans', num_clusters=4)
kmeans_results4 = pull()

kmeans3 = create_model('kmeans', num_clusters=5)
plot_model(kmeans, plot='cluster')
plot_model(kmeans, plot='tsne')
plot_model(kmeans, plot='elbow')


plot_model(kmeans, plot='distance')
kmeans_results5 = pull()

results_df.loc['Silhouette']['PCA(c=3)']=kmeans_results3['Silhouette'][0]
results_df.loc['Silhouette']['PCA(c=4)']=kmeans_results4['Silhouette'][0]
results_df.loc['Silhouette']['PCA(c=5)']=kmeans_results5['Silhouette'][0]
results_df.loc['Calinski-Harabasz']['PCA(c=3)']=kmeans_results3['Calinski-Harabasz'][0]
results_df.loc['Calinski-Harabasz']['PCA(c=4)']=kmeans_results4['Calinski-Harabasz'][0]
results_df.loc['Calinski-Harabasz']['PCA(c=5)']=kmeans_results5['Calinski-Harabasz'][0]
results_df.loc['Davies-Bouldin']['PCA(c=3)']=kmeans_results3['Davies-Bouldin'][0]
results_df.loc['Davies-Bouldin']['PCA(c=4)']=kmeans_results4['Davies-Bouldin'][0]
results_df.loc['Davies-Bouldin']['PCA(c=5)']=kmeans_results5['Davies-Bouldin'][0]
# Out:
# <style type="text/css">
# </style>
# <table id="T_545cd" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_545cd_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_545cd_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_545cd_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_545cd_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_545cd_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_545cd_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_545cd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_545cd_row0_col0" class="data row0 col0" >0.5512</td>
#       <td id="T_545cd_row0_col1" class="data row0 col1" >561.5936</td>
# ...

# %%
exp_kmeans = setup(data = X, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)


kmeans3 = create_model('kmeans', num_clusters=3)

kmeans_results3 = pull()

kmeans3 = create_model('kmeans', num_clusters=4)
kmeans_results4 = pull()

kmeans3 = create_model('kmeans', num_clusters=5)
kmeans_results5 = pull()

results_df.loc['Silhouette']['T+N(c=3)']=kmeans_results3['Silhouette'][0]
results_df.loc['Silhouette']['T+N(c=4)']=kmeans_results4['Silhouette'][0]
results_df.loc['Silhouette']['T+N(c=5)']=kmeans_results5['Silhouette'][0]
results_df.loc['Calinski-Harabasz']['T+N(c=3)']=kmeans_results3['Calinski-Harabasz'][0]
results_df.loc['Calinski-Harabasz']['T+N(c=4)']=kmeans_results4['Calinski-Harabasz'][0]
results_df.loc['Calinski-Harabasz']['T+N(c=5)']=kmeans_results5['Calinski-Harabasz'][0]
results_df.loc['Davies-Bouldin']['T+N(c=3)']=kmeans_results3['Davies-Bouldin'][0]
results_df.loc['Davies-Bouldin']['T+N(c=4)']=kmeans_results4['Davies-Bouldin'][0]
results_df.loc['Davies-Bouldin']['T+N(c=5)']=kmeans_results5['Davies-Bouldin'][0]
# Out:
# <style type="text/css">
# </style>
# <table id="T_8a4b6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8a4b6_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_8a4b6_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_8a4b6_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_8a4b6_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_8a4b6_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_8a4b6_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a4b6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8a4b6_row0_col0" class="data row0 col0" >0.4891</td>
#       <td id="T_8a4b6_row0_col1" class="data row0 col1" >161.8610</td>
# ...

# %%
exp_kmeans = setup(data = X, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore',
      transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)


kmeans3 = create_model('kmeans', num_clusters=3)

plot_model(kmeans3, plot='cluster')
plot_model(kmeans3, plot='tsne')
plot_model(kmeans3, plot='elbow')
plot_model(kmeans3, plot='silhouette')
plot_model(kmeans3, plot='distribution')
plot_model(kmeans3, plot='distance')


kmeans_results3 = pull()

kmeans3 = create_model('kmeans', num_clusters=4)
kmeans_results4 = pull()

kmeans3 = create_model('kmeans', num_clusters=5)
kmeans_results5 = pull()

results_df.loc['Silhouette']['T+N+P(c=3)']=kmeans_results3['Silhouette'][0]
results_df.loc['Silhouette']['T+N+P(c=4)']=kmeans_results4['Silhouette'][0]
results_df.loc['Silhouette']['T+N+P(c=5)']=kmeans_results5['Silhouette'][0]
results_df.loc['Calinski-Harabasz']['T+N+P(c=3)']=kmeans_results3['Calinski-Harabasz'][0]
results_df.loc['Calinski-Harabasz']['T+N+P(c=4)']=kmeans_results4['Calinski-Harabasz'][0]
results_df.loc['Calinski-Harabasz']['T+N+P(c=5)']=kmeans_results5['Calinski-Harabasz'][0]
results_df.loc['Davies-Bouldin']['T+N+P(c=3)']=kmeans_results3['Davies-Bouldin'][0]
results_df.loc['Davies-Bouldin']['T+N+P(c=4)']=kmeans_results4['Davies-Bouldin'][0]
results_df.loc['Davies-Bouldin']['T+N+P(c=5)']=kmeans_results5['Davies-Bouldin'][0]
# Out:
# <style type="text/css">
# </style>
# <table id="T_77983" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_77983_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_77983_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_77983_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_77983_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_77983_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_77983_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_77983_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_77983_row0_col0" class="data row0 col0" >0.4572</td>
#       <td id="T_77983_row0_col1" class="data row0 col1" >246.7813</td>
# ...

# %%
# Out:
# <style type="text/css">
# </style>
# <table id="T_6aa54" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6aa54_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_6aa54_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_6aa54_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_6aa54_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_6aa54_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_6aa54_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6aa54_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6aa54_row0_col0" class="data row0 col0" >0.5528</td>
#       <td id="T_6aa54_row0_col1" class="data row0 col1" >561.6277</td>
# ...

# %%
exp_hclust = setup(data = X, verbose=False)

hclust3 = create_model('hclust', num_clusters=3)

plot_model(hclust3, plot='cluster')
plot_model(hclust3, plot='tsne')
plot_model(hclust3, plot='elbow')



hclust_results3 = pull()

exp_hclust = setup(data = X, verbose=False)
hclust4 = create_model('hclust', num_clusters=4)
hclust_results4 = pull()

exp_hclust = setup(data = X, verbose=False)
hclust5 = create_model('hclust', num_clusters=5)
hclust_results5 = pull()

results_df1.loc['Silhouette']['No data processing(c=3)'] = hclust_results3['Silhouette'][0]
results_df1.loc['Silhouette']['No data processing(c=4)'] = hclust_results4['Silhouette'][0]
results_df1.loc['Silhouette']['No data processing(c=5)'] = hclust_results5['Silhouette'][0]
results_df1.loc['Calinski-Harabasz']['No data processing(c=3)'] = hclust_results3['Calinski-Harabasz'][0]
results_df1.loc['Calinski-Harabasz']['No data processing(c=4)'] = hclust_results4['Calinski-Harabasz'][0]
results_df1.loc['Calinski-Harabasz']['No data processing(c=5)'] = hclust_results5['Calinski-Harabasz'][0]
results_df1.loc['Davies-Bouldin']['No data processing(c=3)'] = hclust_results3['Davies-Bouldin'][0]
results_df1.loc['Davies-Bouldin']['No data processing(c=4)'] = hclust_results4['Davies-Bouldin'][0]
results_df1.loc['Davies-Bouldin']['No data processing(c=5)'] = hclust_results5['Davies-Bouldin'][0]


exp_hclust = setup(data=X, normalize=True, normalize_method='zscore', verbose=False)


hclust3 = create_model('hclust', num_clusters=3)
hclust_results3 = pull()

hclust4 = create_model('hclust', num_clusters=4)
hclust_results4 = pull()

hclust5 = create_model('hclust', num_clusters=5)
hclust_results5 = pull()




results_df1.loc['Silhouette']['Normalized(c=3)'] = hclust_results3['Silhouette'][0]
results_df1.loc['Silhouette']['Normalized(c=4)'] = hclust_results4['Silhouette'][0]
results_df1.loc['Silhouette']['Normalized(c=5)'] = hclust_results5['Silhouette'][0]
results_df1.loc['Calinski-Harabasz']['Normalized(c=3)'] = hclust_results3['Calinski-Harabasz'][0]
results_df1.loc['Calinski-Harabasz']['Normalized(c=4)'] = hclust_results4['Calinski-Harabasz'][0]
results_df1.loc['Calinski-Harabasz']['Normalized(c=5)'] = hclust_results5['Calinski-Harabasz'][0]
results_df1.loc['Davies-Bouldin']['Normalized(c=3)'] = hclust_results3['Davies-Bouldin'][0]
results_df1.loc['Davies-Bouldin']['Normalized(c=4)'] = hclust_results4['Davies-Bouldin'][0]
results_df1.loc['Davies-Bouldin']['Normalized(c=5)'] = hclust_results5['Davies-Bouldin'][0]

exp_hclust = setup(data = X, transformation=True, transformation_method='yeo-johnson', verbose=False)

hclust3 = create_model('hclust', num_clusters=3)
hclust_results3 = pull()

hclust4 = create_model('hclust', num_clusters=4)
plot_model(hclust4, plot='cluster')
plot_model(hclust4, plot='tsne')
plot_model(hclust4, plot='elbow')

hclust_results4 = pull()

hclust5 = create_model('hclust', num_clusters=5)
hclust_results5 = pull()

results_df1.loc['Silhouette']['Transform(c=3)'] = hclust_results3['Silhouette'][0]
results_df1.loc['Silhouette']['Transform(c=4)'] = hclust_results4['Silhouette'][0]
results_df1.loc['Silhouette']['Transform(c=5)'] = hclust_results5['Silhouette'][0]
results_df1.loc['Calinski-Harabasz']['Transform(c=3)'] = hclust_results3['Calinski-Harabasz'][0]
results_df1.loc['Calinski-Harabasz']['Transform(c=4)'] = hclust_results4['Calinski-Harabasz'][0]
results_df1.loc['Calinski-Harabasz']['Transform(c=5)'] = hclust_results5['Calinski-Harabasz'][0]
results_df1.loc['Davies-Bouldin']['Transform(c=3)'] = hclust_results3['Davies-Bouldin'][0]
results_df1.loc['Davies-Bouldin']['Transform(c=4)'] = hclust_results4['Davies-Bouldin'][0]
results_df1.loc['Davies-Bouldin']['Transform(c=5)'] = hclust_results5['Davies-Bouldin'][0]

exp_hclust = setup(data = X, pca=True, pca_method='linear', verbose=False)

hclust3 = create_model('hclust', num_clusters=3)
hclust_results3 = pull()

hclust4 = create_model('hclust', num_clusters=4)
hclust_results4 = pull()

hclust5 = create_model('hclust', num_clusters=5)
plot_model(hclust5, plot='cluster')
plot_model(hclust5, plot='tsne')
plot_model(hclust5, plot='elbow')

hclust_results5 = pull()

results_df1.loc['Silhouette']['PCA(c=3)'] = hclust_results3['Silhouette'][0]
results_df1.loc['Silhouette']['PCA(c=4)'] = hclust_results4['Silhouette'][0]
results_df1.loc['Silhouette']['PCA(c=5)'] = hclust_results5['Silhouette'][0]
results_df1.loc['Calinski-Harabasz']['PCA(c=3)'] = hclust_results3['Calinski-Harabasz'][0]
results_df1.loc['Calinski-Harabasz']['PCA(c=4)'] = hclust_results4['Calinski-Harabasz'][0]
results_df1.loc['Calinski-Harabasz']['PCA(c=5)'] = hclust_results5['Calinski-Harabasz'][0]
results_df1.loc['Davies-Bouldin']['PCA(c=3)'] = hclust_results3['Davies-Bouldin'][0]
results_df1.loc['Davies-Bouldin']['PCA(c=4)'] = hclust_results4['Davies-Bouldin'][0]
results_df1.loc['Davies-Bouldin']['PCA(c=5)'] = hclust_results5['Davies-Bouldin'][0]

exp_hclust = setup(data = X, transformation=True, normalize=True,
      normalize_method='zscore', transformation_method='yeo-johnson', verbose=False)

hclust3 = create_model('hclust', num_clusters=3)
hclust_results3 = pull()

hclust4 = create_model('hclust', num_clusters=4)
hclust_results4 = pull()

hclust5 = create_model('hclust', num_clusters=5)
hclust_results5 = pull()


exp_hclust = setup(data = X, transformation=True, normalize=True,
      normalize_method='zscore', transformation_method='yeo-johnson', verbose=False)

hclust3 = create_model('hclust', num_clusters=3)

hclust_results3 = pull()

hclust4 = create_model('hclust', num_clusters=4)
hclust_results4 = pull()

hclust5 = create_model('hclust', num_clusters=5)
hclust_results5 = pull()

results_df1.loc['Silhouette']['T+N(c=3)'] = hclust_results3['Silhouette'][0]
results_df1.loc['Silhouette']['T+N(c=4)'] = hclust_results4['Silhouette'][0]
results_df1.loc['Silhouette']['T+N(c=5)'] = hclust_results5['Silhouette'][0]
results_df1.loc['Calinski-Harabasz']['T+N(c=3)'] = hclust_results3['Calinski-Harabasz'][0]
results_df1.loc['Calinski-Harabasz']['T+N(c=4)'] = hclust_results4['Calinski-Harabasz'][0]
results_df1.loc['Calinski-Harabasz']['T+N(c=5)'] = hclust_results5['Calinski-Harabasz'][0]
results_df1.loc['Davies-Bouldin']['T+N(c=3)'] = hclust_results3['Davies-Bouldin'][0]
results_df1.loc['Davies-Bouldin']['T+N(c=4)'] = hclust_results4['Davies-Bouldin'][0]
results_df1.loc['Davies-Bouldin']['T+N(c=5)'] = hclust_results5['Davies-Bouldin'][0]

exp_hclust = setup(data = X, transformation=True, normalize=True, pca=True,
      normalize_method='zscore',
      transformation_method='yeo-johnson',
      pca_method='linear', verbose=False)

hclust3 = create_model('hclust', num_clusters=3)

plot_model(hclust3, plot='cluster')
plot_model(hclust3, plot='tsne')
plot_model(hclust3, plot='elbow')


hclust_results3 = pull()

hclust4 = create_model('hclust', num_clusters=4)
hclust_results4 = pull()

hclust5 = create_model('hclust', num_clusters=5)
hclust_results5 = pull()

results_df1.loc['Silhouette']['T+N+P(c=3)'] = hclust_results3['Silhouette'][0]
results_df1.loc['Silhouette']['T+N+P(c=4)'] = hclust_results4['Silhouette'][0]
results_df1.loc['Silhouette']['T+N+P(c=5)'] = hclust_results5['Silhouette'][0]
results_df1.loc['Calinski-Harabasz']['T+N+P(c=3)'] = hclust_results3['Calinski-Harabasz'][0]
results_df1.loc['Calinski-Harabasz']['T+N+P(c=4)'] = hclust_results4['Calinski-Harabasz'][0]
results_df1.loc['Calinski-Harabasz']['T+N+P(c=5)'] = hclust_results5['Calinski-Harabasz'][0]
results_df1.loc['Davies-Bouldin']['T+N+P(c=3)'] = hclust_results3['Davies-Bouldin'][0]
results_df1.loc['Davies-Bouldin']['T+N+P(c=4)'] = hclust_results4['Davies-Bouldin'][0]
results_df1.loc['Davies-Bouldin']['T+N+P(c=5)'] = hclust_results5['Davies-Bouldin'][0]
# Out:
# <style type="text/css">
# </style>
# <table id="T_55b63" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_55b63_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_55b63_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_55b63_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_55b63_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_55b63_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_55b63_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55b63_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_55b63_row0_col0" class="data row0 col0" >0.5543</td>
#       <td id="T_55b63_row0_col1" class="data row0 col1" >558.0579</td>
# ...

# %%
exp_meanshift = setup(data=X, verbose=False)

meanshift3 = create_model('meanshift', num_clusters=3)

plot_model(meanshift3, plot='cluster')
plot_model(meanshift3, plot='tsne')

meanshift_results3 = pull()

exp_meanshift = setup(data=X, verbose=False)
meanshift4 = create_model('meanshift', num_clusters=4)
meanshift_results4 = pull()

exp_meanshift = setup(data=X, verbose=False)
meanshift5 = create_model('meanshift', num_clusters=5)
meanshift_results5 = pull()

results_df2.loc['Silhouette']['No data processing(c=3)'] = meanshift_results3['Silhouette'][0]
results_df2.loc['Silhouette']['No data processing(c=4)'] = meanshift_results4['Silhouette'][0]
results_df2.loc['Silhouette']['No data processing(c=5)'] = meanshift_results5['Silhouette'][0]
results_df2.loc['Calinski-Harabasz']['No data processing(c=3)'] = meanshift_results3['Calinski-Harabasz'][0]
results_df2.loc['Calinski-Harabasz']['No data processing(c=4)'] = meanshift_results4['Calinski-Harabasz'][0]
results_df2.loc['Calinski-Harabasz']['No data processing(c=5)'] = meanshift_results5['Calinski-Harabasz'][0]
results_df2.loc['Davies-Bouldin']['No data processing(c=3)'] = meanshift_results3['Davies-Bouldin'][0]
results_df2.loc['Davies-Bouldin']['No data processing(c=4)'] = meanshift_results4['Davies-Bouldin'][0]
results_df2.loc['Davies-Bouldin']['No data processing(c=5)'] = meanshift_results5['Davies-Bouldin'][0]


exp_meanshift = setup(data=X, normalize=True, normalize_method='zscore', verbose=False)


meanshift_model = create_model('meanshift')
meanshift_results = pull()



results_df2.loc['Silhouette']['Normalized(c=3)'] = hclust_results3['Silhouette'][0]
results_df2.loc['Silhouette']['Normalized(c=4)'] = hclust_results4['Silhouette'][0]
results_df2.loc['Silhouette']['Normalized(c=5)'] = hclust_results5['Silhouette'][0]
results_df2.loc['Calinski-Harabasz']['Normalized(c=3)'] = hclust_results3['Calinski-Harabasz'][0]
results_df2.loc['Calinski-Harabasz']['Normalized(c=4)'] = hclust_results4['Calinski-Harabasz'][0]
results_df2.loc['Calinski-Harabasz']['Normalized(c=5)'] = hclust_results5['Calinski-Harabasz'][0]
results_df2.loc['Davies-Bouldin']['Normalized(c=3)'] = hclust_results3['Davies-Bouldin'][0]
results_df2.loc['Davies-Bouldin']['Normalized(c=4)'] = hclust_results4['Davies-Bouldin'][0]
results_df2.loc['Davies-Bouldin']['Normalized(c=5)'] = hclust_results5['Davies-Bouldin'][0]

exp_meanshift = setup(data=X, transformation=True, transformation_method='yeo-johnson', verbose=False)

meanshift3 = create_model('meanshift', num_clusters=3)
meanshift_results3 = pull()

meanshift4 = create_model('meanshift', num_clusters=4)
plot_model(meanshift4, plot='cluster')
plot_model(meanshift4, plot='tsne')


meanshift_results4 = pull()

meanshift5 = create_model('meanshift', num_clusters=5)
meanshift_results5 = pull()

results_df2.loc['Silhouette']['Transform(c=3)'] = meanshift_results3['Silhouette'][0]
results_df2.loc['Silhouette']['Transform(c=4)'] = meanshift_results4['Silhouette'][0]
results_df2.loc['Silhouette']['Transform(c=5)'] = meanshift_results5['Silhouette'][0]
results_df2.loc['Calinski-Harabasz']['Transform(c=3)'] = meanshift_results3['Calinski-Harabasz'][0]
results_df2.loc['Calinski-Harabasz']['Transform(c=4)'] = meanshift_results4['Calinski-Harabasz'][0]
results_df2.loc['Calinski-Harabasz']['Transform(c=5)'] = meanshift_results5['Calinski-Harabasz'][0]
results_df2.loc['Davies-Bouldin']['Transform(c=3)'] = meanshift_results3['Davies-Bouldin'][0]
results_df2.loc['Davies-Bouldin']['Transform(c=4)'] = meanshift_results4['Davies-Bouldin'][0]
results_df2.loc['Davies-Bouldin']['Transform(c=5)'] = meanshift_results5['Davies-Bouldin'][0]

exp_meanshift = setup(data=X, pca=True, pca_method='linear', verbose=False)

meanshift3 = create_model('meanshift', num_clusters=3)
meanshift_results3 = pull()

meanshift4 = create_model('meanshift', num_clusters=4)
meanshift_results4 = pull()

meanshift5 = create_model('meanshift', num_clusters=5)
plot_model(meanshift5, plot='cluster')
plot_model(meanshift5, plot='tsne')


meanshift_results5 = pull()

results_df2.loc['Silhouette']['PCA(c=3)'] = meanshift_results3['Silhouette'][0]
results_df2.loc['Silhouette']['PCA(c=4)'] = meanshift_results4['Silhouette'][0]
results_df2.loc['Silhouette']['PCA(c=5)'] = meanshift_results5['Silhouette'][0]
results_df2.loc['Calinski-Harabasz']['PCA(c=3)'] = meanshift_results3['Calinski-Harabasz'][0]
results_df2.loc['Calinski-Harabasz']['PCA(c=4)'] = meanshift_results4['Calinski-Harabasz'][0]
results_df2.loc['Calinski-Harabasz']['PCA(c=5)'] = meanshift_results5['Calinski-Harabasz'][0]
results_df2.loc['Davies-Bouldin']['PCA(c=3)'] = meanshift_results3['Davies-Bouldin'][0]
results_df2.loc['Davies-Bouldin']['PCA(c=4)'] = meanshift_results4['Davies-Bouldin'][0]
results_df2.loc['Davies-Bouldin']['PCA(c=5)'] = meanshift_results5['Davies-Bouldin'][0]

exp_meanshift = setup(data=X, transformation=True, normalize=True,
      normalize_method='zscore', transformation_method='yeo-johnson', verbose=False)

meanshift3 = create_model('meanshift', num_clusters=3)
meanshift_results3 = pull()

meanshift4 = create_model('meanshift', num_clusters=4)
meanshift_results4 = pull()

meanshift5 = create_model('meanshift', num_clusters=5)
meanshift_results5 = pull()

results_df2.loc['Silhouette']['T+N(c=3)'] = meanshift_results3['Silhouette'][0]
results_df2.loc['Silhouette']['T+N(c=4)'] = meanshift_results4['Silhouette'][0]
results_df2.loc['Silhouette']['T+N(c=5)'] = meanshift_results5['Silhouette'][0]
results_df2.loc['Calinski-Harabasz']['T+N(c=3)'] = meanshift_results3['Calinski-Harabasz'][0]
results_df2.loc['Calinski-Harabasz']['T+N(c=4)'] = meanshift_results4['Calinski-Harabasz'][0]
results_df2.loc['Calinski-Harabasz']['T+N(c=5)'] = meanshift_results5['Calinski-Harabasz'][0]
results_df2.loc['Davies-Bouldin']['T+N(c=3)'] = meanshift_results3['Davies-Bouldin'][0]
results_df2.loc['Davies-Bouldin']['T+N(c=4)'] = meanshift_results4['Davies-Bouldin'][0]
results_df2.loc['Davies-Bouldin']['T+N(c=5)'] = meanshift_results5['Davies-Bouldin'][0]

exp_meanshift = setup(data=X, transformation=True, normalize=True, pca=True,
      normalize_method='zscore',
      transformation_method='yeo-johnson',
      pca_method='linear', verbose=False)

meanshift3 = create_model('meanshift', num_clusters=3)

plot_model(meanshift3, plot='cluster')
plot_model(meanshift3, plot='tsne')


meanshift_results3 = pull()

meanshift4 = create_model('meanshift', num_clusters=4)
meanshift_results4 = pull()

meanshift5 = create_model('meanshift', num_clusters=5)
meanshift_results5 = pull()

results_df2.loc['Silhouette']['T+N+P(c=3)'] = meanshift_results3['Silhouette'][0]
results_df2.loc['Silhouette']['T+N+P(c=4)'] = meanshift_results4['Silhouette'][0]
results_df2.loc['Silhouette']['T+N+P(c=5)'] = meanshift_results5['Silhouette'][0]
results_df2.loc['Calinski-Harabasz']['T+N+P(c=3)'] = meanshift_results3['Calinski-Harabasz'][0]
results_df2.loc['Calinski-Harabasz']['T+N+P(c=4)'] = meanshift_results4['Calinski-Harabasz'][0]
results_df2.loc['Calinski-Harabasz']['T+N+P(c=5)'] = meanshift_results5['Calinski-Harabasz'][0]
results_df2.loc['Davies-Bouldin']['T+N+P(c=3)'] = meanshift_results3['Davies-Bouldin'][0]
results_df2.loc['Davies-Bouldin']['T+N+P(c=4)'] = meanshift_results4['Davies-Bouldin'][0]
# Out:
# <style type="text/css">
# </style>
# <table id="T_fc5cb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc5cb_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_fc5cb_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_fc5cb_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_fc5cb_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_fc5cb_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_fc5cb_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc5cb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fc5cb_row0_col0" class="data row0 col0" >0.6858</td>
#       <td id="T_fc5cb_row0_col1" class="data row0 col1" >509.7038</td>
# ...

# %%
print("Kmean")
results_df
# Out:
# Kmean
#                   No data processing(c=3) No data processing(c=4)  \
# Silhouette                         0.5528                  0.4954
# Calinski-Harabasz                561.6277                529.1967
# Davies-Bouldin                      0.662                  0.7639
#
#                   No data processing(c=5) Normalized(c=3) Normalized(c=4)  \
# Silhouette                         0.4887          0.4599          0.4131
# Calinski-Harabasz                495.5415        241.9044        206.0729
# Davies-Bouldin                      0.806          0.8336          0.9223
#
#                   Normalized(c=5) Transform(c=3) Transform(c=4)  \
# Silhouette                  0.345          0.654         0.6165
# Calinski-Harabasz        202.6359      1164.8165      1350.7879
# Davies-Bouldin             0.9439         0.4883          0.532
#
#                   Transform(c=5)  PCA(c=3)  PCA(c=4)  PCA(c=5) T+N(c=3)  \
# ...

# %%
print("Hierarchical Clustering")
results_df1
# Out:
# Hierarchical Clustering
#                   No data processing(c=3) No data processing(c=4)  \
# Silhouette                         0.5543                   0.489
# Calinski-Harabasz                558.0579                515.0788
# Davies-Bouldin                     0.6563                  0.7953
#
#                   No data processing(c=5) Normalized(c=3) Normalized(c=4)  \
# Silhouette                         0.4844          0.4467          0.4006
# Calinski-Harabasz                488.4849        222.7191        201.2515
# Davies-Bouldin                     0.8204          0.8035          0.9788
#
#                   Normalized(c=5) Transform(c=3) Transform(c=4)  \
# Silhouette                 0.3306         0.6301         0.6007
# Calinski-Harabasz        192.6813       948.9021      1260.6132
# Davies-Bouldin             0.9742         0.4873          0.534
#
#                   Transform(c=5)  PCA(c=3)  PCA(c=4)  PCA(c=5) T+N(c=3)  \
# ...

# %%
print("Mean Shift Clustering")
results_df2
# Out:
# Mean Shift Clustering
#                   No data processing(c=3) No data processing(c=4)  \
# Silhouette                         0.6858                  0.6858
# Calinski-Harabasz                509.7038                509.7038
# Davies-Bouldin                     0.3886                  0.3886
#
#                   No data processing(c=5) Normalized(c=3) Normalized(c=4)  \
# Silhouette                         0.6858          0.4781          0.4272
# Calinski-Harabasz                509.7038           225.3        213.7555
# Davies-Bouldin                     0.3886          0.7434          0.9024
#
#                   Normalized(c=5) Transform(c=3) Transform(c=4)  \
# Silhouette                 0.3569         0.6532         0.6532
# Calinski-Harabasz        202.2256      1161.7898      1161.7898
# Davies-Bouldin             0.9181         0.4881         0.4881
#
#                   Transform(c=5)  PCA(c=3)  PCA(c=4)  PCA(c=5)  T+N(c=3)  \
# ...
